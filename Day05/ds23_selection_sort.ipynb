# %% [markdown]
# ## 선택정렬

# %% [markdown]
# ### 최소값 위치 확인 함수

# %%
def findMinIdx(ary):
    minIdx = 0
    for i in range(1, len(ary)):
        if ary[minIdx] > ary[i]:
            minIdx = i
    return minIdx

# %%
tests = [55, 88, 33, 77, 10]
print(findMinIdx(tests))
# Out:
# 4

# %% [markdown]
# #### 선택정렬 전체

# %%
# 변수선언
before = [188, 162, 168, 120, 50, 150, 177, 105]
after = []

print('정렬전 -->', before)
for _ in range(len(before)):
    minPos = findMinIdx(before)
    after.append(before[minPos])
    del(before[minPos]) # 최소값 삭제

print('정렬후 -->', after)
# Out:
# 정렬전 --> [188, 162, 168, 120, 50, 150, 177, 105]
# 정렬후 --> [50, 105, 120, 150, 162, 168, 177, 188]

# %%
import random

dataBank = []
for i in range(0,10000):
    dataBank.append(random.randint(0,10000))

# %% [markdown]
# #### 개선된 선택정렬
#
# 배열을 두개 만들 필요 없고, 값 교환 기능 학습

# %%
def selectionSort(ary):
    n = len(ary)
    for i in range(0, n-1): # 마지막 인덱스 n-2
        minIdx = i
        for k in range(i+1, n): # 마지막 인덱스 n-1
            if(ary[minIdx] > ary[k]):
                minIdx = k
        tmp = ary[i]
        ary[i] = ary[minIdx]
        ary[minIdx] = tmp
    return ary

# 변수
dataAry = [9, 1, 6, 4] #[188, 162, 168, 120, 50, 150, 177, 105]

#메인 코드 부분
print('정렬 전 -->',dataAry)
dataAry = selectionSort(dataAry)
print('정렬 후 -->', dataAry)
# Out:
# 정렬 전 --> [9, 1, 6, 4]
# 정렬 후 --> [1, 4, 6, 9]

# %% [markdown]
# ### 삽입정렬 Insertion Sort
#
# #### 자신의 삽입위치를 찾는 힘수

# %%
def findInsertIdx(ary, data):
    findIdx = -1
    for i in range(0, len(ary)):
        if ary[i] > data:
            findIdx = i
            break
    if findIdx == -1:
        return len(ary)
    else:
        return findIdx

# %%
testAry = []
print('50이 들어갈 위치', findInsertIdx(testAry, 50))
testAry = [33, 60, 54, 88]
print('55가 들어갈 위치', findInsertIdx(testAry, 55))
# Out:
# 50이 들어갈 위치 0
# 55가 들어갈 위치 1

# %%
before = [188, 162, 168, 120, 50, 150, 177, 105]
after = []

print('정렬 전 --> ', before)
for i in range(len(before)):
    data = before[i]
    idx = findInsertIdx(after, data)
    after.insert(idx, data)
print('정렬 후 --> ', after)
print('원본 --> ', before)
# Out:
# 정렬 전 -->  [188, 162, 168, 120, 50, 150, 177, 105]
# 정렬 후 -->  [50, 105, 120, 150, 162, 168, 177, 188]
# 원본 -->  [188, 162, 168, 120, 50, 150, 177, 105]

# %% [markdown]
# ### 삽입정렬 개선

# %%
def insertionSort(ary):
    n = len(ary)
    for end in range(1, n): # 앞의 값 하나 빼고 끝까지 반복
        for cur in range(end, 0, -1): # 반대로 돌면서
            if ary[cur - 1] > ary[cur]:
                ary[cur-1], ary[cur] = ary[cur], ary[cur-1]# 파이썬의 스왑을 간단하게 할 수 있는 기능
                # tmp = ary[cur - 1]
                # ary[cur- 1] = ary[tmp]
                # ary[cur] = tmp
    return ary

# 변수
dataAry = [188, 162, 168, 120, 20, 150, 177, 105]

#메인 코드 부분
print('정렬 전 -->', dataAry)
dataAry = selectionSort(dataAry)
print('정렬 후 -->', dataAry)
# Out:
# 정렬 전 --> [188, 162, 168, 120, 20, 150, 177, 105]
# 정렬 후 --> [20, 105, 120, 150, 162, 168, 177, 188]

# %%
def selectionSort(ary):
    n = len(ary)
    for end in range(0, n-1): # 앞의 값 하나 빼고 끝까지 반복
        for k in range(i+1, n): # 반대로 돌면서
            if ary[minIdx] > ary[k]:
                ary[cur-1], ary[cur] = ary[cur], ary[cur-1]# 파이썬의 스왑을 간단하게 할 수 있는 기능
                # tmp = ary[cur - 1]
                # ary[cur- 1] = ary[tmp]
                # ary[cur] = tmp
    return ary

# 변수
dataAry = [188, 162, 168, 120, 20, 150, 177, 105]

#메인 코드 부분
print('정렬 전 -->', dataAry)
dataAry = selectionSort(dataAry)
print('정렬 후 -->', dataAry)

# %% [markdown]
# ### 버블 정렬 (Bubble Sort)

# %%
def BubbleSort(ary):
    n = len(ary)
    for end in range(n-1, 0, -1): # n-1 번째 부터 0번까지 역순으로 반복
        print('사이클 -->', ary)
        for cur in range(0, end): # 0부터 n-2까지 반복
            if ary[cur] > ary[cur+1]:
                ary[cur] , ary[cur+1] = ary[cur+1] , ary[cur]
    return ary

# 변수
dataAry = [99999, 666, 7777, 4, 3, 55, 8888, 105]

#메인 코드 부분
print('정렬 전 -->', dataAry)
dataAry = BubbleSort(dataAry)
print('정렬 후 -->', dataAry)
# Out:
# 정렬 전 --> [99999, 666, 7777, 4, 3, 55, 8888, 105]
# 사이클 --> [99999, 666, 7777, 4, 3, 55, 8888, 105]
# 사이클 --> [666, 7777, 4, 3, 55, 8888, 105, 99999]
# 사이클 --> [666, 4, 3, 55, 7777, 105, 8888, 99999]
# 사이클 --> [4, 3, 55, 666, 105, 7777, 8888, 99999]
# 사이클 --> [3, 4, 55, 105, 666, 7777, 8888, 99999]
# 사이클 --> [3, 4, 55, 105, 666, 7777, 8888, 99999]
# 사이클 --> [3, 4, 55, 105, 666, 7777, 8888, 99999]
# 정렬 후 --> [3, 4, 55, 105, 666, 7777, 8888, 99999]

# %% [markdown]
# ### 퀵 정렬(Quick Sort)

# %%
def quickSort(ary):
    n = len(ary)
    if n <= 1:          # 정렬할 것이 하나 이하면 그냥 리턴
        return ary
    pivot = ary[n//2]   # 중간값을 기준값으로 정함
    leftAry, rightAry, midAry = [], [], []
    for num in ary:
        if num < pivot:
            leftAry.append(num)
        elif num > pivot:
            rightAry.append(num)
        else:
            midAry.append(num) # 중복된 값을 고려

    return quickSort(leftAry) + midAry + quickSort(rightAry)

dataAry = [190, 162, 168, 120, 120 , 20, 150, 177, 105]

print('정렬 전 -->', dataAry)
dataAry = quickSort(dataAry)
print('정렬 후 -->', dataAry)
# Out:
# 정렬 전 --> [190, 162, 168, 120, 120, 20, 150, 177, 105]
# 정렬 후 --> [20, 105, 120, 120, 150, 162, 168, 177, 190]

# %%
import random

dataBank = []
for i in range(0,10000):
    dataBank.append(random.randint(0,10000))

# %%
dataBank.sort(reverse=True) # 파이썬이 기본적으로 지원하는 정렬
                            # 리버스 옵션이 없으면 순차 정렬

# %%
dataBank.sort() # 오름차순 정렬

#  20,
#  21,
#  22,
#  23,
#  24,
#  25,
#  27,
#  27,
#  32,
#  33,
#  34,
#  34,
#  36,
#  36,
#  36,
#  37,
#  38,
#  38,
#  41,
#  43,
#  43,
#  43,
#  45,
#  46,
#  46,
#  46,
#  53,
#  55,
#  56,
#  56,
#  57,
#  59,
#  61,
#  62,
#  64,
#  64,
#  64,
#  65,
#  65,
#  66,
#  66,
#  66,
#  67,
#  67,
#  69,
#  70,
#  71,
#  75,
#  77,
#  77,
#  77,
#  79,
#  79,
#  79,
#  80,
#  81,
#  84,
#  85,
#  85,
#  86,
#  89,
#  90,
#  90,
#  92,
#  93,
#  94,
#  95,
#  95,
#  97,
#  98,
#  98,
#  99,
#  99,
#  100,
#  102,
#  102,
#  102,
#  103,
#  103,
#  103,
#  103,
#  104,
#  105,
#  108,
#  109,
#  109,
#  110,
#  110,
#  110,
#  112,
#  112,
#  112,
#  113,
#  113,
#  115,
#  115,
#  116,
#  116,
#  117,
#  118,
#  120,
#  121,
#  121,
#  123,
#  124,
#  125,
#  125,
#  125,
#  126,
#  126,
#  128,
#  129,
#  129,
#  129,
#  131,
#  131,
#  134,
#  136,
#  137,
#  140,
#  140,
#  140,
#  142,
#  145,
#  145,
#  145,
#  145,
#  147,
#  149,
#  149,
#  150,
#  151,
#  152,
#  152,
#  153,
#  154,
#  154,
#  156,
#  157,
#  159,
#  162,
#  163,
#  164,
#  165,
#  166,
#  167,
#  168,
#  168,
#  169,
#  169,
#  169,
#  170,
#  170,
#  173,
#  175,
#  176,
#  177,
#  178,
#  179,
#  179,
#  181,
#  182,
#  182,
#  182,
#  182,
#  182,
#  183,
#  183,
#  184,
#  187,
#  188,
#  189,
#  190,
#  190,
#  191,
#  191,
#  191,
#  192,
#  193,
#  196,
#  196,
#  196,
#  197,
#  197,
#  198,
#  198,
#  201,
#  203,
#  205,
#  206,
#  206,
#  207,
#  207,
#  208,
#  210,
#  210,
#  211,
#  211,
#  213,
#  214,
#  214,
#  215,
#  215,
#  215,
#  216,
#  216,
#  218,
#  218,
#  219,
#  221,
#  221,
#  222,
#  222,
#  224,
#  225,
#  226,
#  230,
#  232,
#  232,
#  232,
#  233,
#  233,
#  234,
#  234,
#  241,
#  241,
#  241,
#  241,
#  244,
#  244,
#  244,
#  245,
#  247,
#  248,
#  252,
#  252,
#  253,
#  255,
#  255,
#  256,
#  258,
#  260,
#  261,
#  262,
#  262,
#  263,
#  264,
#  265,
#  265,
#  266,
#  267,
#  268,
#  268,
#  269,
#  270,
#  271,
#  272,
#  272,
#  273,
#  273,
#  274,
#  274,
#  275,
#  276,
#  278,
#  279,
#  279,
#  280,
#  281,
#  281,
#  282,
#  283,
#  284,
#  284,
#  284,
#  285,
#  286,
#  287,
#  288,
#  288,
#  288,
#  289,
#  290,
#  290,
#  290,
#  291,
#  292,
#  293,
#  296,
#  297,
#  297,
#  298,
#  299,
#  299,
#  301,
#  303,
#  304,
#  306,
#  308,
#  308,
#  309,
#  309,
#  310,
#  310,
#  311,
#  312,
#  312,
#  312,
#  314,
#  319,
#  326,
#  327,
#  327,
#  328,
#  328,
#  330,
#  331,
#  332,
#  334,
#  335,
#  335,
#  338,
#  341,
#  342,
#  342,
#  342,
#  343,
#  345,
#  347,
#  349,
#  350,
#  351,
#  352,
#  352,
#  354,
#  354,
#  355,
#  355,
#  357,
#  357,
#  360,
#  362,
#  364,
#  365,
#  365,
#  366,
#  366,
#  367,
#  367,
#  367,
#  368,
#  373,
#  373,
#  374,
#  374,
#  375,
#  377,
#  377,
#  378,
#  378,
#  378,
#  379,
#  379,
#  379,
#  380,
#  380,
#  383,
#  383,
#  383,
#  385,
#  385,
#  386,
#  387,
#  389,
#  389,
#  389,
#  389,
#  390,
#  390,
#  390,
#  391,
#  392,
#  392,
#  392,
#  393,
#  396,
#  397,
#  398,
#  400,
#  400,
#  400,
#  401,
#  401,
#  402,
#  406,
#  406,
#  406,
#  407,
#  408,
#  408,
#  411,
#  411,
#  412,
#  413,
#  413,
#  416,
#  416,
#  418,
#  419,
#  421,
#  422,
#  423,
#  425,
#  425,
#  426,
#  428,
#  428,
#  429,
#  434,
#  435,
#  436,
#  437,
#  437,
#  437,
#  439,
#  439,
#  443,
#  444,
#  446,
#  448,
#  449,
#  449,
#  451,
#  451,
#  452,
#  452,
#  453,
#  454,
#  454,
#  454,
#  455,
#  455,
#  455,
#  458,
#  460,
#  460,
#  461,
#  462,
#  462,
#  464,
#  464,
#  466,
#  466,
#  467,
#  469,
#  470,
#  471,
#  471,
#  474,
#  475,
#  475,
#  475,
#  475,
#  476,
#  478,
#  478,
#  479,
#  482,
#  485,
#  486,
#  486,
#  486,
#  487,
#  488,
#  489,
#  490,
#  491,
#  492,
#  493,
#  493,
#  495,
#  497,
#  497,
#  497,
#  497,
#  497,
#  498,
#  499,
#  500,
#  504,
#  505,
#  505,
#  505,
#  505,
#  505,
#  506,
#  507,
#  507,
#  509,
#  509,
#  510,
#  511,
#  512,
#  513,
#  515,
#  516,
#  517,
#  518,
#  518,
#  518,
#  518,
#  519,
#  519,
#  520,
#  520,
#  521,
#  521,
#  522,
#  525,
#  525,
#  525,
#  525,
#  526,
#  526,
#  528,
#  529,
#  530,
#  530,
#  531,
#  531,
#  531,
#  531,
#  532,
#  535,
#  536,
#  536,
#  538,
#  539,
#  539,
#  539,
#  540,
#  541,
#  543,
#  545,
#  547,
#  549,
#  550,
#  550,
#  552,
#  552,
#  553,
#  553,
#  555,
#  555,
#  556,
#  558,
#  558,
#  559,
#  560,
#  560,
#  561,
#  562,
#  563,
#  564,
#  564,
#  568,
#  568,
#  569,
#  569,
#  571,
#  572,
#  573,
#  573,
#  574,
#  574,
#  575,
#  575,
#  575,
#  577,
#  578,
#  579,
#  579,
#  581,
#  583,
#  585,
#  585,
#  587,
#  588,
#  591,
#  591,
#  593,
#  594,
#  597,
#  597,
#  598,
#  598,
#  598,
#  599,
#  600,
#  601,
#  604,
#  604,
#  606,
#  606,
#  607,
#  607,
#  607,
#  608,
#  608,
#  611,
#  613,
#  614,
#  615,
#  616,
#  616,
#  617,
#  618,
#  619,
#  621,
#  623,
#  623,
#  623,
#  623,
#  625,
#  625,
#  628,
#  630,
#  630,
#  632,
#  633,
#  634,
#  635,
#  635,
#  635,
#  636,
#  639,
#  639,
#  640,
#  641,
#  641,
#  641,
#  644,
#  644,
#  646,
#  647,
#  647,
#  647,
#  649,
#  650,
#  651,
#  653,
#  656,
#  656,
#  659,
#  659,
#  661,
#  663,
#  664,
#  664,
#  665,
#  666,
#  666,
#  667,
#  667,
#  668,
#  668,
#  671,
#  671,
#  674,
#  675,
#  675,
#  676,
#  676,
#  677,
#  677,
#  678,
#  679,
#  680,
#  682,
#  684,
#  684,
#  685,
#  685,
#  686,
#  688,
#  688,
#  688,
#  690,
#  693,
#  693,
#  694,
#  695,
#  695,
#  695,
#  696,
#  697,
#  699,
#  701,
#  702,
#  704,
#  704,
#  706,
#  707,
#  708,
#  708,
#  709,
#  710,
#  711,
#  711,
#  713,
#  714,
#  716,
#  716,
#  717,
#  717,
#  717,
#  719,
#  721,
#  721,
#  722,
#  722,
#  724,
#  724,
#  726,
#  726,
#  726,
#  727,
#  727,
#  728,
#  729,
#  730,
#  730,
#  731,
#  733,
#  736,
#  738,
#  740,
#  742,
#  744,
#  744,
#  745,
#  746,
#  748,
#  748,
#  748,
#  748,
#  749,
#  752,
#  753,
#  755,
#  757,
#  760,
#  762,
#  764,
#  764,
#  765,
#  765,
#  767,
#  767,
#  768,
#  770,
#  770,
#  772,
#  773,
#  775,
#  775,
#  781,
#  782,
#  784,
#  786,
#  790,
#  791,
#  794,
#  794,
#  794,
#  795,
#  799,
#  799,
#  801,
#  802,
#  802,
#  805,
#  805,
#  806,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  815,
#  816,
#  816,
#  816,
#  817,
#  819,
#  820,
#  820,
#  821,
#  825,
#  825,
#  826,
#  827,
#  827,
#  828,
#  828,
#  830,
#  831,
#  831,
#  833,
#  833,
#  835,
#  835,
#  835,
#  837,
#  837,
#  837,
#  838,
#  839,
#  840,
#  842,
#  843,
#  845,
#  845,
#  845,
#  846,
#  847,
#  849,
#  849,
#  851,
#  855,
#  856,
#  856,
#  858,
#  858,
#  860,
#  860,
#  861,
#  861,
#  863,
#  863,
#  863,
#  863,
#  864,
#  866,
#  869,
#  870,
#  870,
#  871,
#  873,
#  873,
#  874,
#  874,
#  874,
#  875,
#  875,
#  876,
#  879,
#  881,
#  881,
#  881,
#  882,
#  883,
#  884,
#  885,
#  886,
#  886,
#  887,
#  887,
#  888,
#  889,
#  889,
#  889,
#  890,
#  890,
#  890,
#  891,
#  893,
#  893,
#  894,
#  895,
#  896,
#  896,
#  898,
#  898,
#  899,
#  900,
#  900,
#  901,
#  904,
#  904,
#  905,
#  908,
#  909,
#  909,
#  910,
#  910,
#  910,
#  910,
#  911,
#  914,
#  916,
#  916,
#  919,
#  920,
#  921,
#  922,
#  923,
#  925,
#  925,
#  925,
#  925,
#  925,
#  925,
#  926,
#  926,
#  929,
#  932,
#  933,
#  934,
#  935,
#  935,
#  936,
#  939,
#  940,
#  940,
#  941,
#  942,
#  943,
#  945,
#  948,
#  949,
#  950,
#  951,
#  952,
#  956,
#  956,
#  957,
#  957,
#  957,
#  958,
#  958,
#  959,
#  960,
#  960,
#  961,
#  962,
#  965,
#  965,
#  967,
#  967,
#  970,
#  973,
#  974,
#  974,
#  976,
#  976,
#  976,
#  977,
#  977,
#  978,
#  978,
#  979,
#  979,
#  980,
#  981,
#  982,
#  983,
#  984,
#  987,
#  988,
#  989,
#  989,
#  990,
#  992,
#  993,
#  994,
#  ...]
